# %% [markdown]
# # Environment & Config Check

# %%
from dotenv import load_dotenv
import os
import numpy as np

# %%
load_dotenv()
# Out:
# True

# %%
# Checks to see if API key exists
print("API_KEY present:", os.getenv("API_KEY") is not None)
# Out:
# API_KEY present: True

# %%
# small NumPy array
arr = np.array([1, 2, 3, 4, 5])
print("Array:", arr)
print("Mean:", arr.mean())
print("Array * 10:", arr * 10)
# Out:
# Array: [1 2 3 4 5]
# Mean: 3.0
# Array * 10: [10 20 30 40 50]
